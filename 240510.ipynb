# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# **1. 데이터 불러오기**

# %%
data = [[1,'Alice'],[2, 'Bob'],[3, 'Charlie']]
df = pd.DataFrame(data, columns=['ID', 'Name'])
print(df)
# Out:
#    ID     Name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie

# %%
df1 = pd.read_csv('data.csv',encoding = 'UTF-8')
print(df1)
# Out:
#    name   age   score
# 0   Kim    27      92
# 1   Lee    33      98
# 2  Park    19      87

# %% [markdown]
# 웹에 있는 데이터 불러오기

# %%
#긴 url을 짧은 변수로 지정하기
url = 'https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv'
df2 = pd.read_csv(url)
print(df2)
# Out:
#       gameId\tcreationTime\tgameDuration\tseasonId\twinner\tfirstBlood\tfirstTower\tfirstInhibitor\tfirstBaron\tfirstDragon\tfirstRiftHerald\tt1_champ1id\tt1_champ1_sum1\tt1_champ1_sum2\tt1_champ2id\tt1_champ2_sum1\tt1_champ2_sum2\tt1_champ3id\tt1_champ3_sum1\tt1_champ3_sum2\tt1_champ4id\tt1_champ4_sum1\tt1_champ4_sum2\tt1_champ5id\tt1_champ5_sum1\tt1_champ5_sum2\tt1_towerKills\tt1_inhibitorKills\tt1_baronKills\tt1_dragonKills\tt1_riftHeraldKills\tt1_ban1\tt1_ban2\tt1_ban3\tt1_ban4\tt1_ban5\tt2_champ1id\tt2_champ1_sum1\tt2_champ1_sum2\tt2_champ2id\tt2_champ2_sum1\tt2_champ2_sum2\tt2_champ3id\tt2_champ3_sum1\tt2_champ3_sum2\tt2_champ4id\tt2_champ4_sum1\tt2_champ4_sum2\tt2_champ5id\tt2_champ5_sum1\tt2_champ5_sum2\tt2_towerKills\tt2_inhibitorKills\tt2_baronKills\tt2_dragonKills\tt2_riftHeraldKills\tt2_ban1\tt2_ban2\tt2_ban3\tt2_ban4\tt2_ban5
# 0      3326086514\t1504279457970\t1949\t9\t1\t2\t1\t1...
# 1      3229566029\t1497848803862\t1851\t9\t1\t1\t1\t1...
# ...

# %%
url = 'https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv'
df2 = pd.read_csv(url,delimiter='\t')
print(df2)
# Out:
#            gameId   creationTime  gameDuration  seasonId  winner  firstBlood  \
# 0      3326086514  1504279457970          1949         9       1           2
# 1      3229566029  1497848803862          1851         9       1           1
# 2      3327363504  1504360103310          1493         9       1           2
# 3      3326856598  1504348503996          1758         9       1           1
# 4      3330080762  1504554410899          2094         9       1           2
# ...           ...            ...           ...       ...     ...         ...
# 51485  3308904636  1503076540231          1944         9       2           1
# 51486  3215685759  1496957179355          3304         9       2           1
# 51487  3322765040  1504029863961          2156         9       2           2
# 51488  3256675373  1499562036246          1475         9       2           2
# 51489  3317333020  1503612754059          1445         9       1           1
#
# ...

# %%
df3 = pd.read_excel('BoxOffice.xlsx')
print(df3)
# Out:
#       순위         영화명        개봉일           매출액       관객수  스크린수    상영횟수 대표국적  \
# 0      1          명량 2014-07-30  135758208810  17615844  1587  188724   한국
# 1      2        극한직업 2019-01-23  139655543516  16266338  2003  292816   한국
# 2      3   신과함께-죄와 벌 2017-12-20  115727528087  14414658  1912  214631   한국
# 3      4        국제시장 2014-12-17  110945002730  14264059  1044  212698   한국
# 4      5  어벤져스: 엔드게임 2019-04-24  122492181020  13977602  2835  246433   미국
# ..   ...         ...        ...           ...       ...   ...     ...  ...
# 195  196         스파이 2013-09-05   24513098305   3436092   785   72805   한국
# 196  197   그것만이 내 세상 2018-01-17   27457704382   3420287   956   95444   한국
# 197  198    토이 스토리 4 2019-06-20   28763352540   3400623  1336   85913   미국
# 198  199           돈 2019-03-20   28870244062   3389125  1431  120809   한국
# 199  200    맨 인 블랙 3 2012-05-24   27301520070   3379762   770   69538   미국
#
#         국적                  배급사
# 0       한국            (주)씨제이이엔엠
# ...

# %%
df4 = pd.read_excel('data.xlsx')
df4
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 2  A반  오지수  남   NaN    NaN   응시   확인
# 3  B반  김선후  남  33.0   44.0   응시  NaN
# 4  A반  하진희  여   0.0   85.0   응시  NaN
# 5  A반  강현진  남   NaN    NaN  NaN  NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 8  A반  김성희  남   NaN    NaN  NaN   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %% [markdown]
# **2. 데이터 확인하기**

# %% [markdown]
# 2.1 데이터의 일부 보기

# %%
df4.head(3)
# Out:
#      이름 성별    국어    수학 응시여부 확인여부
# 반
# A반  구이서  남  90.0  89.0   응시   확인
# B반  김이정  여  78.0  45.0   응시   확인
# A반  오지수  남   NaN   NaN   응시   확인

# %%
df4.tail(3)
# Out:
#      이름 성별    국어     수학 응시여부 확인여부
# 반
# B반  박서준  여  78.0   45.0   응시   확인
# A반  김성희  남   NaN    NaN  NaN   확인
# B반  이지서  여  86.0  100.0   응시   확인

# %% [markdown]
# 2.2 데이터프레임에 대한 정보 보기

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   반       10 non-null     object
#  1   이름      10 non-null     object
#  2   성별      10 non-null     object
#  3   국어      7 non-null      float64
#  4   수학      7 non-null      float64
#  5   응시여부    8 non-null      object
#  6   확인여부    7 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 688.0+ bytes

# %% [markdown]
# 10 entries / 0 to 9: : 10개의 데이터
# 6 columns : 6개의 칼럼
# non-null : 결측치 값 개수 확인
# object : 문자
# float : 실수

# %% [markdown]
# 2.3 특정 칼럼의 데이터만 보기

# %%
df4.반
# Out:
# 0    A반
# 1    B반
# 2    A반
# 3    B반
# 4    A반
# 5    A반
# 6    B반
# 7    B반
# 8    A반
# 9    B반
# Name: 반, dtype: object

# %%
df4['반']
# Out:
# 0    A반
# 1    B반
# 2    A반
# 3    B반
# 4    A반
# 5    A반
# 6    B반
# 7    B반
# 8    A반
# 9    B반
# Name: 반, dtype: object

# %%
df4[['반','이름']]
# Out:
#     반   이름
# 0  A반  구이서
# 1  B반  김이정
# 2  A반  오지수
# 3  B반  김선후
# 4  A반  하진희
# 5  A반  강현진
# 6  B반  김진솔
# 7  B반  박서준
# 8  A반  김성희
# 9  B반  이지서

# %% [markdown]
# 2.4 특정 행의 데이터만 보기

# %%
df4[0:3]
# Out:
#     반   이름 성별    국어    수학 응시여부 확인여부
# 0  A반  구이서  남  90.0  89.0   응시   확인
# 1  B반  김이정  여  78.0  45.0   응시   확인
# 2  A반  오지수  남   NaN   NaN   응시   확인

# %%
df4['반'][0:3]
# Out:
# 0    A반
# 1    B반
# 2    A반
# Name: 반, dtype: object

# %% [markdown]
# 2.5 행과 칼럼을 지정해서 데이터 보기

# %%
df4.loc[0,['이름']]
# Out:
# 이름    구이서
# Name: 0, dtype: object

# %% [markdown]
# 2.6 조건 연산 결과 출력 (true/false)

# %%
condition_result = df4['국어'] >= 80
print(condition_result)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9     True
# Name: 국어, dtype: bool

# %% [markdown]
# 2.7 데이터 프레임에서 조건에 맞는 데이터 보기

# %%
df4[df4['국어'] >= 80]
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %%
df4.query('국어 >= 80')
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %% [markdown]
# 2.8 데이터프레임의 데이터 정렬

# %%
df4.sort_values(by='국어', ascending=False)
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 3  B반  김선후  남  33.0   44.0   응시  NaN
# 4  A반  하진희  여   0.0   85.0   응시  NaN
# 2  A반  오지수  남   NaN    NaN   응시   확인
# 5  A반  강현진  남   NaN    NaN  NaN  NaN
# 8  A반  김성희  남   NaN    NaN  NaN   확인

# %% [markdown]
# 2.9 데이터프레임의 속성값 정보 보기

# %%
df4.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df4.columns
# Out:
# Index(['반', '이름', '성별', '국어', '수학', '응시여부', '확인여부'], dtype='object')

# %%
df4.size
#행의 개수 x 칼럼 개수
# Out:
# 70

# %% [markdown]
# **3. 데이터 집계**

# %% [markdown]
# 3.1 전체 기본 통계 출력

# %%
df4.describe()
# Out:
#              국어          수학
# count   7.00000    7.000000
# mean   65.00000   71.000000
# std    34.82815   25.053277
# min     0.00000   44.000000
# 25%    55.50000   45.000000
# 50%    78.00000   85.000000
# 75%    88.00000   89.000000
# max    90.00000  100.000000

# %% [markdown]
# 3.2 칼럼값별 데이터 개수 보기

# %%
df4['성별'].value_counts()
# Out:
# 성별
# 남    6
# 여    4
# Name: count, dtype: int64

# %% [markdown]
# 3.3 개별 칼럼의 통계값 구하기

# %%
df4['국어'].mean()
# Out:
# 65.0

# %% [markdown]
# 3.4 그룹별 통계값 구하기

# %% [markdown]
# **4. 결측치 처리**

# %% [markdown]
# 4.1 결측치 확인

# %%
df4.isna()
# Out:
#        반     이름     성별     국어     수학   응시여부   확인여부
# 0  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False
# 2  False  False  False   True   True  False  False
# 3  False  False  False  False  False  False   True
# 4  False  False  False  False  False  False   True
# 5  False  False  False   True   True   True   True
# 6  False  False  False  False  False  False  False
# 7  False  False  False  False  False  False  False
# 8  False  False  False   True   True   True  False
# 9  False  False  False  False  False  False  False

# %%
df4.isna().sum()
# Out:
# 반       0
# 이름      0
# 성별      0
# 국어      3
# 수학      3
# 응시여부    2
# 확인여부    3
# dtype: int64

# %% [markdown]
# 4.2 결측치 채우기

# %%
df4.fillna(0)
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 2  A반  오지수  남   0.0    0.0   응시   확인
# 3  B반  김선후  남  33.0   44.0   응시    0
# 4  A반  하진희  여   0.0   85.0   응시    0
# 5  A반  강현진  남   0.0    0.0    0    0
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 8  A반  김성희  남   0.0    0.0    0   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %%
df4.fillna({'국어':100})
# Out:
#     반   이름 성별     국어     수학 응시여부 확인여부
# 0  A반  구이서  남   90.0   89.0   응시   확인
# 1  B반  김이정  여   78.0   45.0   응시   확인
# 2  A반  오지수  남  100.0    NaN   응시   확인
# 3  B반  김선후  남   33.0   44.0   응시  NaN
# 4  A반  하진희  여    0.0   85.0   응시  NaN
# 5  A반  강현진  남  100.0    NaN  NaN  NaN
# 6  B반  김진솔  남   90.0   89.0   응시   확인
# 7  B반  박서준  여   78.0   45.0   응시   확인
# 8  A반  김성희  남  100.0    NaN  NaN   확인
# 9  B반  이지서  여   86.0  100.0   응시   확인

# %% [markdown]
# 4.3 결측치가 있는 데이터 삭제

# %%
df4.dropna()
#axis=0/1, subset=['칼럼명']
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %% [markdown]
# **5. 데이터프레임의 변경**

# %% [markdown]
# 5.1 새 칼럼 추가

# %%
df4['총점'] = df4['국어'] + df4['수학']
df4
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부     총점
# 0  A반  구이서  남  90.0   89.0   응시   확인  179.0
# 1  B반  김이정  여  78.0   45.0   응시   확인  123.0
# 2  A반  오지수  남   NaN    NaN   응시   확인    NaN
# 3  B반  김선후  남  33.0   44.0   응시  NaN   77.0
# 4  A반  하진희  여   0.0   85.0   응시  NaN   85.0
# 5  A반  강현진  남   NaN    NaN  NaN  NaN    NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인  179.0
# 7  B반  박서준  여  78.0   45.0   응시   확인  123.0
# 8  A반  김성희  남   NaN    NaN  NaN   확인    NaN
# 9  B반  이지서  여  86.0  100.0   응시   확인  186.0

# %% [markdown]
# 5.2 행/칼럼 삭제

# %%
df4.drop('총점', axis=1)
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 2  A반  오지수  남   NaN    NaN   응시   확인
# 3  B반  김선후  남  33.0   44.0   응시  NaN
# 4  A반  하진희  여   0.0   85.0   응시  NaN
# 5  A반  강현진  남   NaN    NaN  NaN  NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 8  A반  김성희  남   NaN    NaN  NaN   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %% [markdown]
# 5.3 항목값의 일괄변경

# %%
df4.replace('남자', 'M')
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부     총점
# 0  A반  구이서  남  90.0   89.0   응시   확인  179.0
# 1  B반  김이정  여  78.0   45.0   응시   확인  123.0
# 2  A반  오지수  남   NaN    NaN   응시   확인    NaN
# 3  B반  김선후  남  33.0   44.0   응시  NaN   77.0
# 4  A반  하진희  여   0.0   85.0   응시  NaN   85.0
# 5  A반  강현진  남   NaN    NaN  NaN  NaN    NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인  179.0
# 7  B반  박서준  여  78.0   45.0   응시   확인  123.0
# 8  A반  김성희  남   NaN    NaN  NaN   확인    NaN
# 9  B반  이지서  여  86.0  100.0   응시   확인  186.0

# %% [markdown]
# **실습 1**

# %% [markdown]
# 1. 데이터를 이용하여 데이터프레임을 생성하세요

# %%
dfm = pd.DataFrame({'학생':['John','Alice', 'Bob', 'Emily'],
                   '수학':[90,87,78,92],
                   '영어':[85,91,80,88],
                   '과학':[88,89,85,82]})
dfm
# Out:
#       학생  수학  영어  과학
# 0   John  90  85  88
# 1  Alice  87  91  89
# 2    Bob  78  80  85
# 3  Emily  92  88  82

# %% [markdown]
# 2. 생성한 데이터프레임의 요약 통계 정보를 출력하세요

# %%
dfm.describe()
# Out:
#               수학         영어         과학
# count   4.000000   4.000000   4.000000
# mean   86.750000  86.000000  86.000000
# std     6.184658   4.690416   3.162278
# min    78.000000  80.000000  82.000000
# 25%    84.750000  83.750000  84.250000
# 50%    88.500000  86.500000  86.500000
# 75%    90.500000  88.750000  88.250000
# max    92.000000  91.000000  89.000000

# %% [markdown]
# 3. 생성한 데이터프레임에서 '수학' 점수가 가장 높은 학생의 정보를 출력하세요

# %%
dfm[dfm['수학']==dfm['수학'].max()]
# Out:
#       학생  수학  영어  과학
# 3  Emily  92  88  82

# %% [markdown]
# 4. 생성한 데이터프레임에서 '수학' 점수가 90점 이상인 학생의 정보를 출력하세요

# %%
dfm[dfm['수학']>=90]
# Out:
#       학생  수학  영어  과학
# 0   John  90  85  88
# 3  Emily  92  88  82

# %% [markdown]
# **실습 2**

# %% [markdown]
# BoxOffice.xlsx 파일을 데이터프레임으로 생성하기

# %% [markdown]
# 1. 데이터프레임을 생성한 후 데이터프레임의 정보를 출력하시오

# %%
dfs = pd.read_excel('BoxOffice.xlsx')
dfs
# Out:
#       순위         영화명        개봉일           매출액       관객수  스크린수    상영횟수 대표국적  \
# 0      1          명량 2014-07-30  135758208810  17615844  1587  188724   한국
# 1      2        극한직업 2019-01-23  139655543516  16266338  2003  292816   한국
# 2      3   신과함께-죄와 벌 2017-12-20  115727528087  14414658  1912  214631   한국
# 3      4        국제시장 2014-12-17  110945002730  14264059  1044  212698   한국
# 4      5  어벤져스: 엔드게임 2019-04-24  122492181020  13977602  2835  246433   미국
# ..   ...         ...        ...           ...       ...   ...     ...  ...
# 195  196         스파이 2013-09-05   24513098305   3436092   785   72805   한국
# 196  197   그것만이 내 세상 2018-01-17   27457704382   3420287   956   95444   한국
# 197  198    토이 스토리 4 2019-06-20   28763352540   3400623  1336   85913   미국
# 198  199           돈 2019-03-20   28870244062   3389125  1431  120809   한국
# 199  200    맨 인 블랙 3 2012-05-24   27301520070   3379762   770   69538   미국
#
#         국적                  배급사
# 0       한국            (주)씨제이이엔엠
# ...

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      200 non-null    int64
#  1   영화명     200 non-null    object
#  2   개봉일     200 non-null    datetime64[ns]
#  3   매출액     200 non-null    int64
#  4   관객수     200 non-null    int64
#  5   스크린수    200 non-null    int64
#  6   상영횟수    200 non-null    int64
#  7   대표국적    200 non-null    object
#  8   국적      200 non-null    object
#  9   배급사     200 non-null    object
# dtypes: datetime64[ns](1), int64(5), object(4)
# memory usage: 15.8+ KB

# %% [markdown]
# 2. 대표국적별 영화 편수를 집계하시오

# %%
dfs['대표국적'].value_counts()
# Out:
# 대표국적
# 한국    116
# 미국     82
# 일본      1
# 영국      1
# Name: count, dtype: int64

# %% [markdown]
# 3. 대표국적이 '영국'인 데이터를 출력하시오

# %%
dfs[dfs['대표국적']=='영국']
# Out:
#       순위     영화명        개봉일          매출액      관객수  스크린수   상영횟수 대표국적  국적  \
# 194  195  어바웃 타임 2013-12-05  25312684300  3449451   568  67267   영국  영국
#
#                      배급사
# 194  유니버설픽쳐스인터내셔널 코리아(유)

# %% [markdown]
# 4. 대표국적별 최상위 순위를 출력하시오

# %%
dfs.groupby('대표국적')['순위'].min()
# Out:
# 대표국적
# 미국      5
# 영국    195
# 일본    172
# 한국      1
# Name: 순위, dtype: int64
